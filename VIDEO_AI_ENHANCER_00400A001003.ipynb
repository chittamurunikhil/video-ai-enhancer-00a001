# %%
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting tensorflow-intel==2.17.0 (from tensorflow)
#   Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl (385.2 MB)
# Installing collected packages: tensorflow-intel, tensorflow
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ADMIN\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\tensorflow\\include\\external\\com_github_grpc_grpc\\src\\core\\ext\\filters\\client_channel\\lb_policy\\grpclb\\client_load_reporting_filter.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-4.43.3-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.7 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/43.7 kB 162.5 kB/s eta 0:00:01
#      -------------------------- ----------- 30.7/43.7 kB 186.2 kB/s eta 0:00:01
#      ----------------------------------- -- 41.0/43.7 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 43.7/43.7 kB 177.7 kB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.43.3-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.4 MB 653.6 kB/s eta 0:00:15
#     --------------------------------------- 0.1/9.4 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/9.4 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.4 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.4 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.4 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.2/9.4 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.4 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.4 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.4 MB 2.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.4 MB 2.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.4/9.4 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.7/9.4 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.8/9.4 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.8/9.4 MB 2.6 MB/s eta 0:00:03
#    ------------ --------------------------- 3.0/9.4 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.4 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.4 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 3.2/9.4 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.4/9.4 MB 2.5 MB/s eta 0:00:03
#    -------------- ------------------------- 3.5/9.4 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 3.6/9.4 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.4 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.4 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.4 MB 2.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.4 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 4.3/9.4 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 4.4/9.4 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 4.4/9.4 MB 2.5 MB/s eta 0:00:03
#    ------------------ --------------------- 4.4/9.4 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 4.5/9.4 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 4.6/9.4 MB 2.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.8/9.4 MB 2.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.8/9.4 MB 2.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.9/9.4 MB 2.4 MB/s eta 0:00:02
#    -------------------- ------------------- 4.9/9.4 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.4 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.4 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.3/9.4 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.4 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.4 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.4 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.4 MB 2.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.4 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 5.7/9.4 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 5.9/9.4 MB 2.3 MB/s eta 0:00:02
#    ------------------------ --------------- 5.9/9.4 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.0/9.4 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.1/9.4 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 6.2/9.4 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.4 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 6.4/9.4 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 6.5/9.4 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 6.5/9.4 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.6/9.4 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.7/9.4 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.7/9.4 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.0/9.4 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 7.1/9.4 MB 2.2 MB/s eta 0:00:02
#    ------------------------------ --------- 7.2/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.4/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.5/9.4 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.5/9.4 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.4 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.4 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.7/9.4 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.4 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 7.9/9.4 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 7.9/9.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.0/9.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.4 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.3/9.4 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.6/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.8/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.8/9.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.4 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.0/9.4 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.4 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 2.1 MB/s eta 0:00:00
# Installing collected packages: transformers
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ADMIN\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# import tensorflow_hub as hub

# module_path = 'https://tfhub.dev/deepmind/biggan-256/2'  # BigGAN-256 TFHub module
# model = hub.load(module_path)

# import cv2
# import numpy as np
# # from tensorflow.keras.models import load_model

# # # Function to load BigGAN model (replace with your model path)
# # def load_biggan_model(model_path):
# #   model = load_model(model_path)
# #   return model

# # Function to preprocess video frame (adjust based on BigGAN input requirements)
# def preprocess_frame(frame):
#   # Resize, normalize, or apply other transformations
#   frame = cv2.resize(frame, (256, 256))  # Example resize to 256x256
#   frame = frame / 255.0  # Example normalization
#   return frame

# # Function to generate animation frame using BigGAN
# def generate_animation_frame(model, noise):
#   latent = model.layers[1](noise)  # Assuming first layer handles noise
#   img = model.predict(latent)
#   return img[0]  # Assuming model outputs a batch of images

# if __name__ == "__main__":
#   # # Load BigGAN model
#   # model = load_biggan_model("path/to/biggan_model.h5")

#   # Specify input and output video paths
#   input_video_path = "/content/2.mp4"
#   output_video_path = "/content/output_animation.mp4"

#   # Open video capture
#   cap = cv2.VideoCapture(input_video_path)

#   # Process each frame (consider error handling)
#   processed_frames = []
#   while True:
#     ret, frame = cap.read()
#     if not ret:
#       break

#     # Preprocess frame
#     preprocessed_frame = preprocess_frame(frame)

#     # Generate random noise for BigGAN
#     noise = np.random.randn(1, model.layers[1].input_shape[1])

#     # Generate animation frame
#     animation_frame = generate_animation_frame(model, noise)

#     # Optionally, post-process animation frame (e.g., color correction)

#     processed_frames.append(animation_frame.astype(np.uint8))  # Convert back to uint8 for video writing

#   cap.release()

#   # Create output video (adjust FPS and other parameters as needed)
#   fourcc = cv2.VideoWriter_fourcc(*"mp4v")  # Change codec if needed
#   out = cv2.VideoWriter(output_video_path, fourcc, 24.0, (animation_frame.shape[1], animation_frame.shape[0]))
#   for frame in processed_frames:
#     out.write(frame)
#   out.release()

#   print("Animation video created!")

# %%
# import tensorflow_hub as hub
# import cv2
# import numpy as np

# # Load TFHub BigGAN module
# module_path = 'https://tfhub.dev/deepmind/biggan-256/2'
# model = hub.load(module_path)

# # Preprocess video frame (adjust as needed for BigGAN input requirements)
# def preprocess_frame(frame):
#   frame = cv2.resize(frame, (256, 256))  # Resize to module's input size
#   frame = frame / 255.0  # Normalize
#   return frame

# # Generate animation frame using BigGAN TFHub module
# def generate_animation_frame(model, noise):
#   # TFHub modules typically expect preprocessing within the module itself
#   img = model(noise)[0]  # Directly generate image from noise
#   return img

# if __name__ == "__main__":
#   input_video_path = "/content/2.mp4"
#   output_video_path = "/content/output_animation.mp4"

#   cap = cv2.VideoCapture(input_video_path)
#   processed_frames = []

#   while True:
#     ret, frame = cap.read()
#     if not ret:
#       break

#     preprocessed_frame = preprocess_frame(frame)
#     noise = np.random.randn(1, 128)  # Adjust noise dimensions based on module requirements
#     animation_frame = generate_animation_frame(model, noise)
#     processed_frames.append(animation_frame.astype(np.uint8))

#   cap.release()

#   fourcc = cv2.VideoWriter_fourcc(*"mp4v")
#   out = cv2.VideoWriter(output_video_path, fourcc, 24.0, (256, 256))  # Match output size to module
#   for frame in processed_frames:
#     out.write(frame)
#   out.release()

#   print("Animation video created!")

# %%
# !pip install opencv-python moviepy stylegan2-pytorch

# %%
# import cv2

# # Load pre-trained pose estimation model (replace with your preferred model)
# # net = cv2.dnn.readNetFromCaffe("/content/pose_deploy.prototxt", "path/to/pose_model.caffemodel")
# net = cv2.dnn.readNetFromCaffe("/content/pose_deploy.prototxt", "/content/pose_iter_440000.caffemodel")


# def estimate_pose(frame):
#   # Preprocess frame (resize, normalization, etc.)
#   blob = cv2.dnn.blobFromImage(frame, 1.0, (300, 300), (10.0, 10.0, 10.0), swapRB=True, crop=False)
#   net.setInput(blob)
#   detections = net.forward()

#   # Parse detections and extract keypoints (modify based on model output)
#   keypoints = []
#   for i in range(detections.shape[0]):
#     confidence = detections[i, 2]
#     if confidence > 0.5:
#       x = detections[i, 3] * frame.shape[1]
#       y = detections[i, 4] * frame.shape[0]
#       keypoints.append((int(x), int(y)))
#   return keypoints
# from stylegan2_pytorch import StyleGAN2

# # Load pre-trained StyleGAN2 generator (replace with your desired style)
# generator = StyleGAN2.load_generator("path/to/stylegan2-ffhq-config.yaml")

# def generate_animation_frame(noise):
#   # Generate an image from random noise
#   latent = generator.style_mod.get_style_from_noise(noise)
#   img = generator(latent)
#   return img.detach().cpu().numpy()[0]
# import cv2
# from moviepy.editor import VideoFileClip

# def process_video(input_video_path, output_video_path, animation_style, fps=24):
#   # Load video
#   clip = VideoFileClip(input_video_path)

#   # Process each frame (consider pose estimation integration here)
#   processed_frames = []
#   for frame in clip.iter_frames():
#     # Optionally, extract human pose here
#     # keypoints = estimate_pose(frame)

#     # Generate animation frame with style transfer
#     noise = np.random.randn(1, generator.z_dim)
#     animation_frame = generate_animation_frame(noise)

#     # Optionally, adjust animation frame based on pose (e.g., warping)

#     processed_frames.append(animation_frame)

#   # Create output video with desired FPS
#   new_clip = VideoFileClip(processed_frames, fps=fps)
#   new_clip.write_videofile(output_video_path)

# if __name__ == "__main__":
#   input_video_path = "/content/2.mp4"
#   output_video_path = "/content/output_animation.mp4"
#   animation_style = "path/to/stylegan2-ffhq-config.yaml"  # Replace with your style
#   process_video(input_video_path, output_video_path, animation_style)

# %%
# # https://huggingface.co/sayakpaul/whitebox-cartoonizer
# import cv2
# import numpy as np
# import requests
# import tensorflow as tf
# from huggingface_hub import snapshot_download
# from PIL import Image


# def resize_crop(image):
#     h, w, c = np.shape(image)
#     if min(h, w) > 720:
#         if h > w:
#             h, w = int(720 * h / w), 720
#         else:
#             h, w = 720, int(720 * w / h)
#     image = cv2.resize(image, (w, h), interpolation=cv2.INTER_AREA)
#     h, w = (h // 8) * 8, (w // 8) * 8
#     image = image[:h, :w, :]
#     return image


# def download_image(url):
#     image = Image.open(requests.get(url, stream=True).raw)
#     image = image.convert("RGB")
#     image = np.array(image)
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#     return image


# def preprocess_image(image):
#     image = resize_crop(image)
#     image = image.astype(np.float32) / 127.5 - 1
#     image = np.expand_dims(image, axis=0)
#     image = tf.constant(image)
#     return image


# # Load the model and extract concrete function.
# model_path = snapshot_download("sayakpaul/whitebox-cartoonizer")
# loaded_model = tf.saved_model.load(model_path)
# concrete_func = loaded_model.signatures["serving_default"]

# # # Download and preprocess image.
# # image_url = "https://huggingface.co/spaces/sayakpaul/cartoonizer-demo-onnx/resolve/main/mountain.jpeg"
# # image = download_image(image_url)
# image = cv2.imread("/content/swapped00a012.jpg")
# preprocessed_image = preprocess_image(image)

# # Run inference.
# result = concrete_func(preprocessed_image)["final_output:0"]

# # Post-process the result and serialize it.
# output = (result[0].numpy() + 1.0) * 127.5
# output = np.clip(output, 0, 255).astype(np.uint8)
# output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
# output_image = Image.fromarray(output)
# output_image.save("result.jpeg")

# %%
# # https://huggingface.co/sayakpaul/whitebox-cartoonizer
# import cv2
# import numpy as np
# import requests
# import tensorflow as tf
# from huggingface_hub import snapshot_download
# from PIL import Image


# def resize_crop(image):
#     h, w, c = np.shape(image)
#     if min(h, w) > 720:
#         if h > w:
#             h, w = int(720 * h / w), 720
#         else:
#             h, w = 720, int(720 * w / h)
#     image = cv2.resize(image, (w, h), interpolation=cv2.INTER_AREA)
#     h, w = (h // 8) * 8, (w // 8) * 8
#     image = image[:h, :w, :]
#     return image


# def download_image(url):
#     image = Image.open(requests.get(url, stream=True).raw)
#     image = image.convert("RGB")
#     image = np.array(image)
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#     return image


# def preprocess_image(image):
#     image = resize_crop(image)
#     image = image.astype(np.float32) / 127.5 - 1
#     image = np.expand_dims(image, axis=0)
#     image = tf.constant(image)
#     return image


# # Load the model and extract concrete function.
# model_path = snapshot_download("sayakpaul/whitebox-cartoonizer")
# loaded_model = tf.saved_model.load(model_path)
# concrete_func = loaded_model.signatures["serving_default"]

# # # Download and preprocess image.
# # image_url = "https://huggingface.co/spaces/sayakpaul/cartoonizer-demo-onnx/resolve/main/mountain.jpeg"
# # image = download_image(image_url)
# image = cv2.VideoCapture("/content/London Trip on Winter - Made with Clipchamp.mp4")
# preprocessed_image = preprocess_image(image)

# # Run inference.
# result = concrete_func(preprocessed_image)["final_output:0"]

# # Post-process the result and serialize it.
# output = (result[0].numpy() + 1.0) * 127.5
# output = np.clip(output, 0, 255).astype(np.uint8)
# output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
# output_image = Image.fromarray(output)
# output_image.save("result1.jpeg")

# %% [markdown]
# # YOUTUBE VIDEO DOWNLOADING

# %%
# !pip install pytube
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytube in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (15.0.0)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# uncomment total only local video extraction
# # # Import libraries
# # import pytube

# # # Define function to download video
# # def download_video(url, output_path="."):
# #   """Downloads a YouTube video to the specified output path.

# #   Args:
# #       url: The URL of the YouTube video to download.
# #       output_path: The path to save the downloaded video (optional).
# #   """
# #   try:
# #     # Create a YouTube object
# #     youtube = pytube.YouTube(url)

# #     # Get the highest resolution stream (modify for specific resolution if needed)
# #     video_stream = youtube.streams.get_highest_resolution()

# #     # Download the video
# #     video_stream.download(output_path=output_path)

# #     print("Video downloaded successfully!")
# #   except Exception as e:
# #     print(f"An error occurred: {e}")

# # # Example usage
# # video_url = "https://www.youtube.com/watch?v=gtw2T55VXQQ"  # Replace with your desired video URL
# # download_video(video_url)

# %%
import pytube

def download_video(url, output_path="."):
    """Downloads a YouTube video to the specified output path and returns the file path.

    Args:
        url: The URL of the YouTube video to download.
        output_path: The path to save the downloaded video (optional).

    Returns:
        The file path of the downloaded video.
    """
    try:
        # Create a YouTube object
        youtube = pytube.YouTube(url)

        # Get the highest resolution stream (modify for specific resolution if needed)
        video_stream = youtube.streams.get_highest_resolution()

        # Download the video and get the file path
        file_path = video_stream.download(output_path=output_path)

        print(f"Video downloaded successfully! File path: {file_path}")
        return file_path
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example usage
video_url = "https://www.youtube.com/watch?v=bBpqasvGPNE"  # Replace with your desired video URL
downloaded_file_path = download_video(video_url)
# Out:
# An error occurred: get_throttling_function_name: could not find match for multiple

# %%
# !pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2024.7.9-py3-none-any.whl.metadata (169 kB)
#      ---------------------------------------- 0.0/169.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/169.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/169.5 kB ? eta -:--:--
#      -------- ---------------------------- 41.0/169.5 kB 326.8 kB/s eta 0:00:01
#      ----------------------- ------------ 112.6/169.5 kB 731.4 kB/s eta 0:00:01
#      ------------------------------ ----- 143.4/169.5 kB 774.0 kB/s eta 0:00:01
#      ------------------------------------ 169.5/169.5 kB 727.2 kB/s eta 0:00:00
# Requirement already satisfied: brotli in c:\users\admin\anaconda3\lib\site-packages (from yt-dlp) (1.0.9)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from yt-dlp) (2024.2.2)
# Collecting mutagen (from yt-dlp)
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pycryptodomex (from yt-dlp)
#   Downloading pycryptodomex-3.20.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting requests<3,>=2.32.2 (from yt-dlp)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: urllib3<3,>=1.26.17 in c:\users\admin\anaconda3\lib\site-packages (from yt-dlp) (2.0.7)
# Collecting websockets>=12.0 (from yt-dlp)
#   Downloading websockets-12.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.2->yt-dlp) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.32.2->yt-dlp) (3.4)
# Downloading yt_dlp-2024.7.9-py3-none-any.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    - -------------------------------------- 0.1/3.1 MB 2.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.2/3.1 MB 2.0 MB/s eta 0:00:02
#    --- ------------------------------------ 0.3/3.1 MB 2.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.1 MB 2.2 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.1 MB 2.2 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.1 MB 2.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.1 MB 2.1 MB/s eta 0:00:02
#    ------ --------------------------------- 0.5/3.1 MB 2.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.6/3.1 MB 1.6 MB/s eta 0:00:02
#    --------- ------------------------------ 0.7/3.1 MB 1.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.8/3.1 MB 1.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.8/3.1 MB 1.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.9/3.1 MB 1.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.9/3.1 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 1.0/3.1 MB 1.5 MB/s eta 0:00:02
#    ------------- -------------------------- 1.0/3.1 MB 1.5 MB/s eta 0:00:02
#    -------------- ------------------------- 1.1/3.1 MB 1.5 MB/s eta 0:00:02
#    --------------- ------------------------ 1.2/3.1 MB 1.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.4/3.1 MB 1.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.4/3.1 MB 1.6 MB/s eta 0:00:02
#    -------------------- ------------------- 1.6/3.1 MB 1.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.7/3.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.7/3.1 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.7/3.1 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.1 MB 1.6 MB/s eta 0:00:01
#    ------------------------- -------------- 2.0/3.1 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 2.0/3.1 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.1 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 2.1/3.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.2/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.2/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.2/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.2/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.3/3.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 2.5/3.1 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 2.5/3.1 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.6/3.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.7/3.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 2.8/3.1 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 3.0/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  3.0/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.4 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Downloading websockets-12.0-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ----------------------------- ---------- 92.2/125.0 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 125.0/125.0 kB 1.8 MB/s eta 0:00:00
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
#    ---------------------------------------- 0.0/194.4 kB ? eta -:--:--
#    ------------------ --------------------- 92.2/194.4 kB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 184.3/194.4 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 194.4/194.4 kB 1.7 MB/s eta 0:00:00
# Downloading pycryptodomex-3.20.0-cp35-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.8 MB 2.6 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.8 MB 2.4 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.8 MB 2.4 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.8 MB 2.4 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.8 MB 711.9 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/1.8 MB 927.4 kB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.3 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 1.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/1.8 MB 973.2 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 954.4 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.8 MB 929.3 kB/s eta 0:00:02
#    ------------ --------------------------- 0.6/1.8 MB 913.7 kB/s eta 0:00:02
#    ------------ --------------------------- 0.6/1.8 MB 842.9 kB/s eta 0:00:02
#    ------------- -------------------------- 0.6/1.8 MB 853.3 kB/s eta 0:00:02
#    ------------- -------------------------- 0.6/1.8 MB 805.5 kB/s eta 0:00:02
#    -------------- ------------------------- 0.6/1.8 MB 796.6 kB/s eta 0:00:02
#    --------------- ------------------------ 0.7/1.8 MB 791.5 kB/s eta 0:00:02
#    --------------- ------------------------ 0.7/1.8 MB 784.1 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.7/1.8 MB 791.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 792.6 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.8 MB 807.1 kB/s eta 0:00:02
#    ------------------- -------------------- 0.9/1.8 MB 807.4 kB/s eta 0:00:02
#    -------------------- ------------------- 0.9/1.8 MB 812.6 kB/s eta 0:00:02
#    --------------------- ------------------ 0.9/1.8 MB 817.4 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 845.4 kB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 854.7 kB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 874.2 kB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 874.2 kB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 874.2 kB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 825.1 kB/s eta 0:00:01
#    -------------------------- ------------- 1.2/1.8 MB 812.4 kB/s eta 0:00:01
#    --------------------------- ------------ 1.2/1.8 MB 808.6 kB/s eta 0:00:01
#    --------------------------- ------------ 1.2/1.8 MB 787.7 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.8 MB 770.9 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 776.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 766.8 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 750.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 742.6 kB/s eta 0:00:01
#    ------------------------------ --------- 1.4/1.8 MB 746.0 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 738.6 kB/s eta 0:00:01
#    ------------------------------- -------- 1.4/1.8 MB 730.7 kB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.8 MB 729.5 kB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.8 MB 722.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 715.3 kB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 715.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 713.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 707.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 696.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 696.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 696.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 681.5 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.8 MB 676.7 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.8 MB 672.3 kB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 676.1 kB/s eta 0:00:01
#    -------------------------------------- - 1.7/1.8 MB 667.6 kB/s eta 0:00:01
#    ---------------------------------------  1.7/1.8 MB 667.3 kB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 663.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 652.3 kB/s eta 0:00:00
# Installing collected packages: websockets, requests, pycryptodomex, mutagen, yt-dlp
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed mutagen-1.47.0 pycryptodomex-3.20.0 requests-2.32.3 websockets-12.0 yt-dlp-2024.7.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.

# %%
# import yt_dlp
# import os


# # Get the current working directory
# current_directory = os.getcwd()

# current_directory.replace("/","\\")


# def download_video(url, output_path="."):
#     """Downloads a YouTube video to the specified output path and returns the file path.

#     Args:
#         url: The URL of the YouTube video to download.
#         output_path: The path to save the downloaded video (optional).

#     Returns:
#         The file path of the downloaded video.
#     """
#     try:
#         ydl_opts = {
#             'format': 'best',
#             'outtmpl': f'{output_path}/%(title)s.%(ext)s',  # Save with title as filename
#         }
        
#         with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#             info_dict = ydl.extract_info(url, download=True)
#             video_title = info_dict.get('title', None)
#             video_ext = info_dict.get('ext', None)
#             file_path = f"{current_directory}/{video_title}.{video_ext}"

#         print(f"Video downloaded successfully! File path: {file_path}")
#         return file_path
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         return None

# # Example usage
# video_url = "https://www.youtube.com/watch?v=bBpqasvGPNE"  # Replace with your desired video URL
# downloaded_file_path = download_video(video_url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bBpqasvGPNE
# [youtube] bBpqasvGPNE: Downloading webpage
# [youtube] bBpqasvGPNE: Downloading ios player API JSON
# [youtube] bBpqasvGPNE: Downloading m3u8 information
# [info] bBpqasvGPNE: Downloading 1 format(s): 18
# [download] Naga Stuti ｜ Naga Nagam Ashrayeham ｜ Naga Consecration Chant.mp4 has already been downloaded
# [download] 100% of   21.38MiB
# Video downloaded successfully! File path: c:\Users\ADMIN\NIKHIL PROGRAM FILES\DOMAIN WISE\VIDEO AND PHOTO EDITING\VIDEOS\AI VIDEO ENHANCER\AI VIDEO ENHANCER 00A001/Naga Stuti | Naga Nagam Ashrayeham | Naga Consecration Chant.mp4

# %%
import yt_dlp
import os
import subprocess

# Get the current working directory
current_directory = os.getcwd()

# Replace forward slashes with backslashes (if needed)
formatted_directory = current_directory.replace("/", "\\")

def download_video(url, output_path="."):
    """Downloads a YouTube video to the specified output path and converts it to Xvid.

    Args:
        url: The URL of the YouTube video to download.
        output_path: The path to save the downloaded video (optional).

    Returns:
        The file path of the downloaded and converted video.
    """
    try:
        ydl_opts = {
            'format': 'best',
            'outtmpl': f'{output_path}/%(title)s.%(ext)s',  # Save with title as filename
        }

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(url, download=True)
            video_title = info_dict.get('title', None)
            video_ext = info_dict.get('ext', None)
            original_file_path = f"{formatted_directory}/{video_title}.{video_ext}"

        # Convert the downloaded video to Xvid using ffmpeg
        converted_file_path = f"{formatted_directory}/{video_title}_xvid.avi"
        ffmpeg_command = [
            'ffmpeg',
            '-i', original_file_path,
            '-vcodec', 'libxvid',
            '-qscale:v', '5',  # Adjust quality scale as needed
            converted_file_path
        ]

        subprocess.run(ffmpeg_command, check=True)

        print(f"Video downloaded and converted successfully! File path: {converted_file_path}")
        return converted_file_path
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Example usage
video_url = "https://www.youtube.com/watch?v=bBpqasvGPNE"  # Replace with your desired video URL
downloaded_file_path = download_video(video_url)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bBpqasvGPNE
# [youtube] bBpqasvGPNE: Downloading webpage
# [youtube] bBpqasvGPNE: Downloading ios player API JSON
# [youtube] bBpqasvGPNE: Downloading m3u8 information
# [info] bBpqasvGPNE: Downloading 1 format(s): 18
# [download] Destination: Naga Stuti ｜ Naga Nagam Ashrayeham ｜ Naga Consecration Chant.mp4
# [download] 100% of   21.38MiB in 00:00:21 at 998.69KiB/s
# An error occurred: [WinError 2] The system cannot find the file specified

# %% [markdown]
# # YOUTUBE AUDIO DOWNLOADING

# %%
# !pip install moviepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: moviepy in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (4.66.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (1.26.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (2.34.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from moviepy) (0.5.1)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imageio<3.0,>=2.5->moviepy) (10.3.0)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (69.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# uncomment total only local video extraction
# # from moviepy.editor import VideoFileClip

# # def extract_audio(video_path, output_path):
# #   """Extracts audio from a video and saves it as a separate MP3 file.

# #   Args:
# #       video_path: Path to the video file.
# #       output_path: Path to save the extracted audio file (MP3 format).
# #   """
# #   video = VideoFileClip(video_path)
# #   audio = video.audio.write_audiofile(output_path)
# #   print(f"Audio extracted and saved to: {output_path}")

# # # Example usage
# # video_path = "/content/Pushpa 2 The Rule Teaser  Allu Arjun  Sukumar  Rashmika Mandanna  Fahadh Faasil  DSP.mp4"  # Replace with your video path

# # audio_path = "extracted_audio.mp3"  # Adjust the output path
# # extract_audio(video_path, audio_path)

# %%
from moviepy.editor import VideoFileClip

def extract_audio(video_path, output_path):
  """Extracts audio from a video and saves it as a separate MP3 file.

  Args:
      video_path: Path to the video file.
      output_path: Path to save the extracted audio file (MP3 format).
  """
  video = VideoFileClip(video_path)
  audio = video.audio.write_audiofile(output_path)
  print(f"Audio extracted and saved to: {output_path}")
download_file_path = "C:\Users\ADMIN\NIKHIL PROGRAM FILES\DOMAIN WISE\VIDEO AND PHOTO EDITING\VIDEOS\AI VIDEO ENHANCER\AI VIDEO ENHANCER 00A001\Naga Stuti ｜ Naga Nagam Ashrayeham ｜ Naga Consecration Chant.mp4"
# Example usage
# video_path = "/content/Pushpa 2 The Rule Teaser  Allu Arjun  Sukumar  Rashmika Mandanna  Fahadh Faasil  DSP.mp4"  # Replace with your video path
video_path = downloaded_file_path

audio_path = f"{downloaded_file_path}_extracted_audio.mp3"  # Adjust the output path
extract_audio(video_path, audio_path)
# Out:
#   Cell In[14], line 13
#     download_file_path = "C:\Users\ADMIN\NIKHIL PROGRAM FILES\DOMAIN WISE\VIDEO AND PHOTO EDITING\VIDEOS\AI VIDEO ENHANCER\AI VIDEO ENHANCER 00A001\Naga Stuti ｜ Naga Nagam Ashrayeham ｜ Naga Consecration Chant.mp4"
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import subprocess
import yt_dlp
import os

# Get the current working directory
current_directory = os.getcwd()
formatted_directory = current_directory.replace("\\", "/")

def download_video(url, output_path="."):
    """Downloads a YouTube video to the specified output path and returns the file path.

    Args:
        url: The URL of the YouTube video to download.
        output_path: The path to save the downloaded video (optional).

    Returns:
        The file path of the downloaded video.
    """
    try:
        ydl_opts = {
            'format': 'best',
            'outtmpl': f'{output_path}/%(title)s.%(ext)s',  # Save with title as filename
        }

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(url, download=True)
            video_title = info_dict.get('title', None)
            video_ext = info_dict.get('ext', None)
            file_path = f"{formatted_directory}/{video_title}.{video_ext}"

        print(f"Video downloaded successfully! File path: {file_path}")
        return file_path
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def extract_audio(video_path, output_path):
    """Extracts audio from a video using ffmpeg and saves it as a separate MP3 file.

    Args:
        video_path: Path to the video file.
        output_path: Path to save the extracted audio file (MP3 format).
    """
    try:
        ffmpeg_command = [
            'ffmpeg',
            '-i', video_path,
            '-q:a', '0',
            '-map', 'a',
            output_path
        ]
        subprocess.run(ffmpeg_command, check=True)
        print(f"Audio extracted and saved to: {output_path}")
    except subprocess.CalledProcessError as e:
        print(f"An error occurred: {e}")

# Example usage
video_url = "https://www.youtube.com/watch?v=bBpqasvGPNE"  # Replace with your desired video URL
downloaded_file_path = download_video(video_url)
if downloaded_file_path:
    audio_path = f"{os.path.splitext(downloaded_file_path)[0]}_extracted_audio.mp3"  # Adjust the output path
    extract_audio(downloaded_file_path, audio_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import subprocess
# ----> 2 import yt_dlp
#       3 import os
#       5 # Get the current working directory
#
# ModuleNotFoundError: No module named 'yt_dlp'

# %% [markdown]
# # breaking the video , editing, joining

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (1.26.4)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install huggingface_hub requests pillow tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: huggingface_hub in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.23.4)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.31.0)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (10.3.0)
# Collecting tensorflow
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2024.2.2)
# Collecting tensorflow-intel==2.17.0 (from tensorflow)
#   Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.11.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl (385.2 MB)
# Installing collected packages: tensorflow-intel, tensorflow
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ADMIN\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\tensorflow\\include\\external\\com_github_grpc_grpc\\src\\core\\ext\\filters\\client_channel\\lb_policy\\grpclb\\client_load_reporting_filter.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# https://huggingface.co/sayakpaul/whitebox-cartoonizer
# 2.1
import cv2
import numpy as np
import requests
import tensorflow as tf
from huggingface_hub import snapshot_download
from PIL import Image


def resize_crop(image):
    h, w, c = np.shape(image)
    if min(h, w) > 720:
        if h > w:
            h, w = int(720 * h / w), 720
        else:
            h, w = 720, int(720 * w / h)
    image = cv2.resize(image, (w, h), interpolation=cv2.INTER_AREA)
    h, w = (h // 8) * 8, (w // 8) * 8
    image = image[:h, :w, :]
    return image


# def download_image(url):
#     image = Image.open(requests.get(url, stream=True).raw)
#     image = image.convert("RGB")
#     image = np.array(image)
#     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#     return image


def preprocess_image(image):
    image = resize_crop(image)
    image = image.astype(np.float32) / 127.5 - 1
    image = np.expand_dims(image, axis=0)
    image = tf.constant(image)
    return image


# Load the model and extract concrete function.
model_path = snapshot_download("sayakpaul/whitebox-cartoonizer")
loaded_model = tf.saved_model.load(model_path)
concrete_func = loaded_model.signatures["serving_default"]

# # # Download and preprocess image.
# # image_url = "https://huggingface.co/spaces/sayakpaul/cartoonizer-demo-onnx/resolve/main/mountain.jpeg"
# # image = download_image(image_url)
# image = cv2.imread("/content/2.png")
# preprocessed_image = preprocess_image(image)

# # Run inference.
# result = concrete_func(preprocessed_image)["final_output:0"]

# # Post-process the result and serialize it.
# output = (result[0].numpy() + 1.0) * 127.5
# output = np.clip(output, 0, 255).astype(np.uint8)
# output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
# output_image = Image.fromarray(output)
# output_image.save("result1.jpeg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 6
#       4 import numpy as np
#       5 import requests
# ----> 6 import tensorflow as tf
#       7 from huggingface_hub import snapshot_download
#       8 from PIL import Image
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      37 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 38 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      39 from tensorflow.python.tools import module_util as _module_util
#      40 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
# 1.1
import cv2
import os

def extract_images(video_path, output_dir, target_fps=30):
  """Extracts images from a video at the specified target frame rate.

  Args:
      video_path (str): Path to the input video file.
      output_dir (str): Path to the output directory for extracted images.
      target_fps (int, optional): Target frame rate for extracted images. Defaults to 30.
  """

  # Create the output directory if it doesn't exist
  os.makedirs(output_dir, exist_ok=True)

  # Open the video capture object
  cap = cv2.VideoCapture(video_path)

  # Check if video was opened successfully
  if not cap.isOpened():
    print("Error opening video file:", video_path)
    return

  # Get the original video frame rate
  original_fps = cap.get(cv2.CAP_PROP_FPS)

  # Calculate the frame step for the target fps
  frame_step = int(max(1, round(original_fps / target_fps)))

  # Count frames and image index
  frame_count = 0
  image_index = 0

  while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
      # End of video
      break

    # Extract image at the specified frame step interval
    if frame_count % frame_step == 0:
      # Create image filename with zero-padding
      image_name = f"image_{image_index:05d}.png"  # Adjust extension as needed (jpg, etc.)
      image_path = os.path.join(output_dir, image_name)

      # Save the extracted image
      cv2.imwrite(image_path, frame)
      image_index += 1
      if image_index % 50 == 0:
        print(image_index)

    frame_count += 1

  # Release the video capture object
  cap.release()
  print("Images extracted successfully!")

# Example usage
# Replace with your video path and desired output directory
# video_path = "/content/Pushpa 2 The Rule Teaser  Allu Arjun  Sukumar  Rashmika Mandanna  Fahadh Faasil  DSP.mp4"
video_path = r"C:\Users\ADMIN\NIKHIL PROGRAM FILES\DOMAIN WISE\VIDEO AND PHOTO EDITING\VIDEOS\AI VIDEO ENHANCER\AI VIDEO ENHANCER 00A001\Naga Stuti ｜ Naga Nagam Ashrayeham ｜ Naga Consecration Chant.mp4"
# video_path = video_path
output_dir = "extracted_images"

extract_images(video_path, output_dir)
# Out:
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# Images extracted successfully!

# %%
# # 1.2
# import cv2
# import wave
# import numpy as np
# def extract_audio(video_path, output_filename="output.wav"):
#   """Extracts audio from a video and saves it to a WAV file.

#   Args:
#       video_path (str): Path to the input video file.
#       output_filename (str, optional): Filename for the saved audio file. Defaults to "output.wav".
#   """

#   # Open the video capture object
#   cap = cv2.VideoCapture(video_path)

#   # Check if video was opened successfully
#   if not cap.isOpened():
#     print("Error opening video file:", video_path)
#     return

#   # Create audio recording object
#   audio_out = wave.open(output_filename, 'wb')

#   # Get video properties (assuming audio sample rate matches video FPS)
#   audio_fps = int(cap.get(cv2.CAP_PROP_FPS))
#   audio_channels = 2  # Adjust for stereo or mono
#   audio_sample_rate = audio_fps

#   # Set audio recording parameters
#   audio_out.setnchannels(audio_channels)
#   audio_out.setsampwidth(2)  # Assuming 16-bit audio (2 bytes per sample)
#   audio_out.setframerate(audio_sample_rate)

#   while True:
#     # Capture frame-by-frame
#     ret, frame = cap.read()

#     if not ret:
#       # End of video
#       break

#     # Read audio data (adjust buffer size if needed)
#     audio_data = cap.read(1)[1]

#     # Check if audio data exists and write to file
#     if np.any(audio_data):
#       audio_out.writeframes(audio_data)

#   # Release resources
#   cap.release()
#   audio_out.close()

#   print("Audio extracted successfully!")

# # Example usage
# # video_path = "path/to/your/video.mp4"
# video_path = "/content/2.mp4"
# output_filename="output.wav"
# extract_audio(video_path,output_filename)

# %%
# # 1.3
# import cv2
# import wave

# def extract_audio_to_mp3(video_path, output_path="audio.mp3"):
#   """Extracts audio from a video and saves it as an MP3 file using OpenCV.

#   Args:
#       video_path (str): Path to the input video file.
#       output_path (str, optional): Path to save the extracted audio file (MP3 format). Defaults to "audio.mp3".
#   """

#   # Open the video capture object
#   cap = cv2.VideoCapture(video_path)

#   # Check if video was opened successfully
#   if not cap.isOpened():
#     print("Error opening video file:", video_path)
#     return

#   # Get audio sample rate and channels
#   audio_fps = int(cap.get(cv2.CAP_PROP_FPS))  # Assuming audio sample rate matches video FPS
#   audio_channels = 2  # Adjust for stereo or mono

#   # Audio recording object
#   audio_out = wave.open(output_path, 'wb')

#   # Set audio recording parameters
#   audio_out.setnchannels(audio_channels)
#   audio_out.setsampwidth(2)  # Assuming 16-bit audio (2 bytes per sample)
#   audio_out.setframerate(audio_fps)

#   while True:
#     # Read video frame (frame is not used here, but required by OpenCV)
#     ret, frame = cap.read()

#     if not ret:
#       # End of video
#       break

#     # Read audio data
#     audio_data = cap.read(1)[1]  # Assuming audio data at index 1

#     # Check if audio data exists and write to file
#     if np.any(audio_data):
#       audio_out.writeframes(audio_data)

#   # Release resources
#   cap.release()
#   audio_out.close()

#   print("Audio extracted successfully!")

# # Example usage
# video_path = "/content/2.mp4"

# extract_audio_to_mp3(video_path)

# %%
# !pip install diffusers

# %%
# #2.2.3.1
# import torch
# from diffusers import StableDiffusionInstructPix2PixPipeline
# from diffusers.utils import load_image

# model_id = "instruction-tuning-sd/cartoonizer"
# pipeline = StableDiffusionInstructPix2PixPipeline.from_pretrained(
#     model_id, torch_dtype=torch.float16, use_auth_token=True
# ).to("cuda")

# %%
# image_path = "/content/1.jpg"
# image = load_image(image_path)

# image = pipeline("cartonize the image completely so that the maximum cartoon is achieved", image=image).images[0]
# image.save("imagecartoon1.png")

# %%
# image_path = "/content/1.jpg"
# image = load_image(image_path)

# image1 = pipeline("Cartoonize the following image", image=image).images[0]
# image1.save("image2.png")

# %%
! pip install diffusers transformers accelerate
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.0)
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (7.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.13.4)
# Requirement already satisfied: huggingface-hub>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.20.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.25.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.31.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.2->diffusers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.2->diffusers) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
# # 2.2.3.2
# import cv2
# from PIL import Image
# from diffusers import StableDiffusionControlNetPipeline, ControlNetModel, UniPCMultistepScheduler
# import torch
# import numpy as np
# from diffusers.utils import load_image

# # image = load_image("https://huggingface.co/lllyasviel/sd-controlnet-hed/resolve/main/images/bird.png")
# image_path = "/content/1.jpg"
# image = load_image(image_path)
# image = np.array(image)

# low_threshold = 100
# high_threshold = 200

# image = cv2.Canny(image, low_threshold, high_threshold)
# image = image[:, :, None]
# image = np.concatenate([image, image, image], axis=2)
# image = Image.fromarray(image)

# controlnet = ControlNetModel.from_pretrained(
#     "lllyasviel/sd-controlnet-canny", torch_dtype=torch.float16
# )

# pipe = StableDiffusionControlNetPipeline.from_pretrained(
#     "runwayml/stable-diffusion-v1-5", controlnet=controlnet, safety_checker=None, torch_dtype=torch.float16
# )

# pipe.scheduler = UniPCMultistepScheduler.from_config(pipe.scheduler.config)

# # Remove if you do not have xformers installed
# # see https://huggingface.co/docs/diffusers/v0.13.0/en/optimization/xformers#installing-xformers
# # for installation instructions
# # pipe.enable_xformers_memory_efficient_attention()

# pipe.enable_model_cpu_offload()

# image = pipe("anime girl", image, num_inference_steps=20).images[0]

# image.save('content/girl_anime_out.png')

# %%
#2.2.1
import cv2
import os

def edit_images(image_dir):
  """Edits images in a directory (replace with your desired edits).

  Args:
      image_dir (str): Path to the directory containing images.
  """
  indexingfor = 0
  for filename in os.listdir(image_dir):
    if filename.endswith(".png") or filename.endswith(".jpg"):  # Adjust extensions
      image_path = os.path.join(image_dir, filename)

      image = cv2.imread(image_path)

      # Convert to grayscale (replace with your edits)
      # grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
      preprocessed_image = preprocess_image(image)

      # Run inference.
      result = concrete_func(preprocessed_image)["final_output:0"]

      # Post-process the result and serialize it.
      output = (result[0].numpy() + 1.0) * 127.5
      output = np.clip(output, 0, 255).astype(np.uint8)
      output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
      output_image = Image.fromarray(output)
      output_image.save(image_path)


      # # image_path = "/content/extracted_images/image_00999.png"
      # # image = load_image(image_path)
      # image = pipeline("Cartoonize the following image", image=image).images[0]
      # image.save(image_path)


      # Save the edited image
      # cv2.imwrite(image_path,  grayscale_image)
      indexingfor += 1
      if indexingfor  % 50 == 0:
        print(indexingfor)
# Example usage
image_dir = "extracted_images"  # Replace with your image directory

edit_images(image_dir)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 47
#      44 # Example usage
#      45 image_dir = "extracted_images"  # Replace with your image directory
# ---> 47 edit_images(image_dir)
#
# Cell In[21], line 20, in edit_images(image_dir)
#      16 image = cv2.imread(image_path)
#      18 # Convert to grayscale (replace with your edits)
#      19 # grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ---> 20 preprocessed_image = preprocess_image(image)
#      22 # Run inference.
#      23 result = concrete_func(preprocessed_image)["final_output:0"]
#
# NameError: name 'preprocess_image' is not defined

# %%
# # 2.2.2.1
# import torch
# from diffusers import DiffusionPipeline

# # Text to Multi-View Diffusion
# text_pipeline = DiffusionPipeline.from_pretrained(
#     "ashawkey/mvdream-sd2.1-diffusers",
#     custom_pipeline="dylanebert/multi_view_diffusion",
#     torch_dtype=torch.float16,
#     trust_remote_code=True,
# ).to("cuda")

# # Image to Multi-View Diffusion
# image_pipeline = DiffusionPipeline.from_pretrained(
#     "ashawkey/imagedream-ipmv-diffusers",
#     custom_pipeline="dylanebert/multi_view_diffusion",
#     torch_dtype=torch.float16,
#     trust_remote_code=True,
# ).to("cuda")

# %%
# !pip install diffusers
# !pip install accelerate einops xformers kiui

# %%
# # 2.2.2.2
# # Imports
# import cv2
# from diffusers import DiffusionPipeline
# import torch
# import numpy as np
# # Model loading (assuming pre-downloaded models)
# text_pipeline = DiffusionPipeline.from_pretrained(
#     "ashawkey/mvdream-sd2.1-diffusers",
#     custom_pipeline="dylanebert/multi_view_diffusion",
#     torch_dtype=torch.float16,
#     trust_remote_code=True,
# ).to("cuda")

# image_pipeline = DiffusionPipeline.from_pretrained(
#     "ashawkey/imagedream-ipmv-diffusers",
#     custom_pipeline="dylanebert/multi_view_diffusion",
#     torch_dtype=torch.float16,
#     trust_remote_code=True,
# ).to("cuda")

# # Load your image (replace with your path)
# image = cv2.imread("/content/1 (1).jpeg")
# image = image.astype(np.float32)

# # Preprocess the image (resize, convert to RGB, etc.)
# # ... (Your image preprocessing logic here)
# if image.dtype != torch.float32:
#   image = torch.from_numpy(image).float()
# # Define your text prompt for modification
# prompt = "The image with a more vibrant color scheme"  # Example prompt

# # Generate the modified image
# generated_image = image_pipeline(
#     image=image,
#     prompt=prompt,
#     guidance_scale=7.5,  # Adjust guidance scale for stronger/weaker modifications (default 7.5)
# )["images"][0]

# # Save or display the generated image
# cv2.imwrite("modified_image.jpg", generated_image)

# # Or display the generated image
# cv2.imshow("Modified Image", generated_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# print("Image modification complete!")

# %%
# import cv2
# import os

# def create_video(image_dir, output_video_path, target_fps=30):
#   """Creates a video from a directory of images at the specified target frame rate.

#   Args:
#       image_dir (str): Path to the directory containing images.
#       output_video_path (str): Path to the output video file.
#       target_fps (int, optional): Target frame rate for the output video. Defaults to 30.
#   """

#   # Get the first image to determine frame size
#   images = [f for f in os.listdir(image_dir) if f.endswith(".png") or f.endswith(".jpg")]  # Adjust extensions for your image format
#   image_path = os.path.join(image_dir, images[0])
#   image = cv2.imread(image_path)
#   height, width, _ = image.shape

#   # Create video writer with appropriate codec (adjust if needed)
#   fourcc = cv2.VideoWriter_fourcc(*'XVID')  # 'XVID' is a common codec, adjust based on your needs
#   video_writer = cv2.VideoWriter(output_video_path, fourcc, target_fps, (width, height))

#   # Add each image to the video writer
#   for filename in images:
#     image_path = os.path.join(image_dir, filename)
#     image = cv2.imread(image_path)
#     video_writer.write(image)

#   # Release the video writer
#   video_writer.release()
#   print("Video created successfully!")

# # Example usage
# image_dir = "extracted_images"  # Replace with your image directory
# output_video_path = "edited_video.mp4"  # Replace with your desired output video path

# create_video(image_dir, output_video_path)

# %%
#3.1
import cv2
import os

def create_video(image_dir, output_video_path, target_fps=30, max_duplicates=1):
  """Creates a video from a directory of images at the specified target frame rate,
  reducing repeated frames and improving video quality.

  Args:
      image_dir (str): Path to the directory containing images.
      output_video_path (str): Path to the output video file.
      target_fps (int, optional): Target frame rate for the output video. Defaults to 30.
      max_duplicates (int, optional): Maximum number of times a consecutive image can be repeated. Defaults to 1 (no duplicates).
  """

  # Track previously seen filenames and their counts
  seen_filenames = {}

  # Get the first image to determine frame size
  images = sorted([f for f in os.listdir(image_dir) if f.endswith(".png") or f.endswith(".jpg")])  # Sort images (optional)
  image_path = os.path.join(image_dir, images[0])
  image = cv2.imread(image_path)
  height, width, _ = image.shape

  # Create video writer with appropriate codec (adjust if needed)
  fourcc = cv2.VideoWriter_fourcc(*'XVID')  # 'XVID' is a common codec, adjust based on your needs
  video_writer = cv2.VideoWriter(output_video_path, fourcc, target_fps, (width, height))

  # Add each image, considering duplicates
  for filename in images:
    image_path = os.path.join(image_dir, filename)
    image = cv2.imread(image_path)

    # Check if image has been seen before and limit consecutive duplicates
    if filename in seen_filenames and seen_filenames[filename] >= max_duplicates:
      continue
    else:
      seen_filenames[filename] = seen_filenames.get(filename, 0) + 1

    video_writer.write(image)

  # Release the video writer
  video_writer.release()
  print("Video created successfully!")

# Example usage
image_dir = "extracted_images"  # Replace with your image directory
output_video_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi EDITED.mp4"  # Replace with your desired output video path
max_duplicates = 2  # Adjust the maximum number of consecutive duplicates allowed

create_video(image_dir, output_video_path, target_fps=30, max_duplicates=max_duplicates)  # Adjust target FPS as needed
# Out:
# Video created successfully!

# %%
# #3.2
# import cv2

# def get_video_info(video_path):
#   """Gets the length (duration) and number of frames in a video using OpenCV.

#   Args:
#       video_path (str): Path to the video file.

#   Returns:
#       tuple: A tuple containing video length (in seconds) and number of frames (int).
#   """

#   # Open the video capture object
#   cap = cv2.VideoCapture(video_path)

#   # Check if video was opened successfully
#   if not cap.isOpened():
#     print("Error opening video file:", video_path)
#     return None, None

#   # Get video properties
#   fps = cap.get(cv2.CAP_PROP_FPS)
#   frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

#   # Calculate video length (duration) in seconds
#   video_length = frame_count / fps

#   # Release resources
#   cap.release()

#   return video_length, frame_count

# # Example usage
# video_path = "/content/edited_video.mp4"

# video_length, frame_count = get_video_info(video_path)

# if video_length is not None and frame_count is not None:
#   print("Video length:", video_length, "seconds")
#   print("Number of frames:", frame_count)
# frpersec = frame_count/ video_length
# print(frpersec)

# %%
# #3.3
# import cv2

# def speed_up_video(video_path, output_path, speed_factor=2):
#   """Speeds up a video by the specified factor using frame skipping.

#   Args:
#       video_path (str): Path to the input video file.
#       output_path (str): Path to save the sped-up video file.
#       speed_factor (float, optional): Speed factor to apply. Defaults to 2 (twice the speed).
#   """

#   # Open the video capture object
#   cap = cv2.VideoCapture(video_path)

#   # Check if video was opened successfully
#   if not cap.isOpened():
#     print("Error opening video file:", video_path)
#     return

#   # Get video properties (assuming constant frame rate)
#   frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#   frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
#   original_fps = cap.get(cv2.CAP_PROP_FPS)
#   new_fps = int(original_fps * speed_factor)

#   # Create video writer for output
#   fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Adjust codec as needed (e.g., 'MP4V' for mp4)
#   out = cv2.VideoWriter(output_path, fourcc, new_fps, (frame_width, frame_height))

#   # Skip frames based on speed factor
#   frame_count = 0
#   while True:
#     # Capture frame-by-frame
#     ret, frame = cap.read()

#     if not ret:
#       # End of video
#       break

#     # Skip frames based on speed factor (consider rounding for smoother playback)
#     if frame_count % int(round(speed_factor)) == 0:
#       out.write(frame)

#     frame_count += 1

#   # Release resources
#   cap.release()
#   out.release()

#   print("Video sped up successfully!")

# # Example usage
# video_path = "/content/edited_video.mp4"
# output_path = "sped_up_video.mp4"
# speed_factor = 1.5  # Adjust speed factor (higher value means faster video)

# speed_up_video(video_path, output_path, speed_factor)

# %%
# # 3.4
# from moviepy.editor import VideoFileClip, AudioFileClip

# def join_audio_video(video_path, audio_path, output_path="output.mp4"):
#   """Joins an audio file with a video and saves the combined result.

#   Args:
#       video_path (str): Path to the input video file (.mp4).
#       audio_path (str): Path to the input audio file.
#       output_path (str, optional): Path to save the combined video file. Defaults to "output.mp4".
#   """

#   # Create video and audio clip objects
#   video_clip = VideoFileClip(video_path)
#   audio_clip = AudioFileClip(audio_path)

#   # Ensure audio duration matches or is longer than video
#   if audio_clip.duration < video_clip.duration:
#     print("Warning: Audio is shorter than video. Padding silence to match video duration.")
#     # Extend audio with silence to match video duration (adjust silence duration as needed)
#     silence = AudioFileClip.silent(video_clip.duration - audio_clip.duration)
#     audio_clip = audio_clip.set_duration(video_clip.duration).concatenate(silence)

#   # Set video's audio to None to avoid duplicate audio tracks
#   video_clip = video_clip.set_audio(None)

#   # Combine video and audio clips
#   final_clip = video_clip.set_audio(audio_clip)

#   # Write the combined video to a file
#   final_clip.write_videofile(output_path)

#   print("Video and audio joined successfully!")

# # Example usage with moviepy installed (assuming pip install moviepy.editor is done)
# video_path = "/content/edited_video.mp4"
# audio_path = "/content/output.wav"  # Adjust audio file format as needed
# output_path="output.mp4"
# join_audio_video(video_path, audio_path,output_path)

# %%
# from moviepy.editor import VideoFileClip, AudioFileClip

# def join_audio_video_fast(video_path, audio_path, output_path="output.mp4"):
#   """Joins a WAV audio file with a video (.mp4) using moviepy.editor.

#   Args:
#       video_path (str): Path to the input video file (.mp4).
#       audio_path (str): Path to the input audio file (WAV format).
#       output_path (str, optional): Path to save the combined video file. Defaults to "output.mp4".
#   """

#   # Create video and audio clip objects
#   video_clip = VideoFileClip(video_path)
#   audio_clip = AudioFileClip(audio_path)

#   # Ensure audio duration matches or is longer than video
#   if audio_clip.duration < video_clip.duration:
#     print("Warning: Audio is shorter than video. Padding silence to match video duration.")
#     # Extend audio with silence to match video duration (adjust silence duration as needed)
#     silence = AudioFileClip.silent(video_clip.duration - audio_clip.duration)
#     audio_clip = audio_clip.set_duration(video_clip.duration).concatenate(silence)

#   # Set video's audio to None to avoid duplicate audio tracks
#   video_clip = video_clip.set_audio(None)

#   # Combine video and audio clips
#   final_clip = video_clip.set_audio(audio_clip)

#   # Write the combined video to a file
#   final_clip.write_videofile(output_path)

#   print("Video and audio joined successfully!")

# video_path = "/content/edited_video.mp4"
# audio_path = "/content/output.wav"  # Adjust audio file format as needed
# output_path="output.mp4"
# join_audio_video(video_path, audio_path,output_path)

# %%
# 3.5.1.1
from moviepy.editor import VideoFileClip

def join_video_audio(video_path, audio_path, output_path):
  """Joins a video with a separate audio track and saves the combined video.

  Args:
      video_path: Path to the video file.
      audio_path: Path to the audio file (MP3 format) to be added.
      output_path: Path to save the combined video file.
  """
  video = VideoFileClip(video_path)
  audio = VideoFileClip(audio_path)
  final_video = video.set_audio(audio)
  final_video.write_videofile(output_path)
  print(f"Video and audio joined and saved to: {output_path}")

# Example usage
video_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi EDITED.mp4"  # Replace with your video path
audio_path = "extracted_audio.mp3"  # Path to the extracted audio
output_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi combined_video.mp4"  # Adjust the output path
join_video_audio(video_path, audio_path, output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-bbba54eb24ec> in <cell line: 22>()
#      20 audio_path = "extracted_audio.mp3"  # Path to the extracted audio
#      21 output_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi combined_video.mp4"  # Adjust the output path
# ---> 22 join_video_audio(video_path, audio_path, output_path)
#
# <ipython-input-5-bbba54eb24ec> in join_video_audio(video_path, audio_path, output_path)
#      11   """
#      12   video = VideoFileClip(video_path)
# ---> 13   audio = VideoFileClip(audio_path)
#      14   final_video = video.set_audio(audio)
#      15   final_video.write_videofile(output_path)
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/VideoFileClip.py in __init__(self, filename, has_mask, audio, audio_buffersize, target_resolution, resize_algorithm, audio_fps, audio_nbytes, verbose, fps_source)
#      86         # Make a reader
#      87         pix_fmt = "rgba" if has_mask else "rgb24"
# ---> 88         self.reader = FFMPEG_VideoReader(filename, pix_fmt=pix_fmt,
#      89                                          target_resolution=target_resolution,
#      90                                          resize_algo=resize_algorithm,
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py in __init__(self, filename, print_infos, bufsize, pix_fmt, check_duration, target_resolution, resize_algo, fps_source)
#      35         infos = ffmpeg_parse_infos(filename, print_infos, check_duration,
#      36                                    fps_source)
# ---> 37         self.fps = infos['video_fps']
#      38         self.size = infos['video_size']
#      39         self.rotation = infos['video_rotation']
#
# KeyError: 'video_fps'

# %%
# 3.5.1.2
# !ffmpeg -i {video_path} -i {audio_path} -c copy {output_path}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# /content/Gangs: No such file or directory

# %%
# 3.5.1.3
import cv2

def combine_video_audio(video_path, audio_path, output_path):
  """Combines a video with an MP3 song and saves the result.

  Args:
      video_path: Path to the video file.
      audio_path: Path to the MP3 song file.
      output_path: Path to save the combined video file.

  Raises:
      ValueError: If video or audio cannot be opened.
  """
  cap = cv2.VideoCapture(video_path)
  if not cap.isOpened():
    raise ValueError("Error opening video file")

  fps = cap.get(cv2.CAP_PROP_FPS)
  width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
  height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

  # Open audio using an external library (e.g., pyaudio, playsound)
  # This example uses a placeholder audio opening function
  audio = open_audio(audio_path)

  # Combine video and audio using external libraries (e.g., moviepy)
  # This example skips combining as cv2 doesn't natively handle audio
  # You'll need to implement audio synchronization and mixing using other libraries

  fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Adjust codec if needed
  out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

  while True:
    ret, frame = cap.read()
    if not ret:
      break
    out.write(frame)

  cap.release()
  out.release()
  # Close audio using the external library's method (placeholder here)
  close_audio(audio)

  print(f"Video and audio combined and saved to: {output_path}")

# Placeholder functions for audio (replace with actual implementations)
def open_audio(audio_path):
  # Implement audio opening using a suitable library (e.g., pyaudio, playsound)
  # This function should return an audio object or handle opening logic
  pass

def close_audio(audio):
  # Implement audio closing using the library's method (placeholder here)
  pass

# Example usage
video_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi.mp4"  # Replace with your video path
audio_path = "extracted_audio.mp3"  # Path to the extracted audio
output_path = "/content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi combined_video.mp4"  # Adjust the output path


try:
  combine_video_audio(video_path, audio_path, output_path)
except ValueError as e:
  print(f"Error: {e}")
# Out:
# Video and audio combined and saved to: /content/Gangs of Godavari - Teaser  Vishwak Sen  Krishna Chaitanya  Yuvan Shankar Raja  S Naga Vamsi combined_video.mp4

# %% [markdown]
# # audio to text generation

# %%
# !pip install transformers accelerate diffusers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Using cached transformers-4.43.3-py3-none-any.whl.metadata (43 kB)
# Collecting accelerate
#   Downloading accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# Collecting diffusers
#   Downloading diffusers-0.29.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from accelerate) (5.9.8)
# Collecting torch>=1.10.0 (from accelerate)
#   Downloading torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting importlib-metadata (from diffusers)
#   Downloading importlib_metadata-8.2.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: Pillow in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from diffusers) (10.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Collecting sympy (from torch>=1.10.0->accelerate)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.10.0->accelerate)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.10.0->accelerate)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.10.0->accelerate) (69.5.1)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting zipp>=0.5 (from importlib-metadata->diffusers)
#   Downloading zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.10.0->accelerate)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached transformers-4.43.3-py3-none-any.whl (9.4 MB)
# Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
#    ---------------------------------------- 0.0/315.1 kB ? eta -:--:--
#    ----- ---------------------------------- 41.0/315.1 kB 1.9 MB/s eta 0:00:01
#    -------------- ------------------------- 112.6/315.1 kB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 163.8/315.1 kB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 235.5/315.1 kB 1.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 235.5/315.1 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 315.1/315.1 kB 1.1 MB/s eta 0:00:00
# Downloading diffusers-0.29.2-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.2 MB
0 MB/s eta 0:00:23
#    ---------------- ----------------------- 83.5/197.8 MB 5.1 MB/s eta 0:00:23
#    ---------------- ----------------------- 83.7/197.8 MB 5.1 MB/s eta 0:00:23
#    ---------------- ----------------------- 83.7/197.8 MB 5.1 MB/s eta 0:00:23
#    ---------------- ----------------------- 83.7/197.8 MB 4.9 MB/s eta 0:00:24
#    ---------------- ----------------------- 84.0/197.8 MB 4.9 MB/s eta 0:00:24
#    ----------------- ---------------------- 84.3/197.8 MB 4.9 MB/s eta 0:00:24
#    ----------------- ---------------------- 84.6/197.8 MB 5.0 MB/s eta 0:00:23
#    ----------------- ---------------------- 84.8/197.8 MB 5.0 MB/s eta 0:00:23
#    ----------------- ---------------------- 85.0/197.8 MB 4.9 MB/s eta 0:00:23
#    ----------------- ---------------------- 85.3/197.8 MB 4.9 MB/s eta 0:00:23
#    ----------------- ---------------------- 85.5/197.8 MB 5.0 MB/s eta 0:00:23
#    ----------------- ---------------------- 85.8/197.8 MB 5.0 MB/s eta 0:00:23
#    ----------------- ---------------------- 86.1/197.8 MB 5.0 MB/s eta 0:00:23
#    ----------------- ---------------------- 86.4/197.8 MB 5.1 MB/s eta 0:00:22
#    ----------------- ---------------------- 86.7/197.8 MB 5.1 MB/s eta 0:00:22
#    ----------------- ---------------------- 86.9/197.8 MB 5.1 MB/s eta 0:00:22
# ...
#    ------------------------------------ --- 180.0/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 180.2/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 180.4/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 180.7/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 180.9/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 181.0/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 181.1/197.8 MB 2.8 MB/s eta 0:00:07
#    ------------------------------------ --- 181.3/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 181.4/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 181.5/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------ --- 181.7/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------ --- 181.8/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.0/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.2/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.4/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.5/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.6/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.7/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.8/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.8/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------ --- 182.9/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------- -- 183.0/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------- -- 183.0/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------- -- 183.0/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------- -- 183.2/197.8 MB 2.8 MB/s eta 0:00:06
#    ------------------------------------- -- 183.4/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 183.6/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 183.7/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 183.8/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 183.9/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 184.0/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 184.2/197.8 MB 2.7 MB/s eta 0:00:06
#    ------------------------------------- -- 184.4/197.8 MB 2.6 MB/s eta 0:00:06
#    ------------------------------------- -- 184.6/197.8 MB 2.6 MB/s eta 0:00:05
#    ------------------------------------- -- 184.8/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 185.0/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 185.2/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 185.4/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 185.5/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 185.8/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 186.0/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 186.1/197.8 MB 2.7 MB/s eta 0:00:05
#    ------------------------------------- -- 186.3/197.8 MB 2.8 MB/s eta 0:00:05
#    ------------------------------------- -- 186.4/197.8 MB 2.8 MB/s eta 0:00:05
#    ------------------------------------- -- 186.5/197.8 MB 2.8 MB/s eta 0:00:05
#    ------------------------------------- -- 186.7/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 186.8/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.0/197.8 MB 2.8 MB/s eta 0:00:04
#    ------------------------------------- -- 187.1/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.1/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.1/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.2/197.8 MB 2.8 MB/s eta 0:00:04
#    ------------------------------------- -- 187.4/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.6/197.8 MB 2.9 MB/s eta 0:00:04
#    ------------------------------------- -- 187.9/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.0/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.1/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.2/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.4/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.6/197.8 MB 3.0 MB/s eta 0:00:04
#    -------------------------------------- - 188.8/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 188.9/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 189.1/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 189.3/197.8 MB 3.3 MB/s eta 0:00:03
#    -------------------------------------- - 189.5/197.8 MB 3.3 MB/s eta 0:00:03
#    -------------------------------------- - 189.6/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 189.8/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.0/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.1/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.3/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.4/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.6/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 190.8/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 191.0/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 191.1/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 191.3/197.8 MB 3.2 MB/s eta 0:00:03
#    -------------------------------------- - 191.3/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 191.3/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 191.4/197.8 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 191.6/197.8 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 191.9/197.8 MB 3.1 MB/s eta 0:00:02
#    -------------------------------------- - 192.1/197.8 MB 3.2 MB/s eta 0:00:02
#    -------------------------------------- - 192.4/197.8 MB 3.2 MB/s eta 0:00:02
#    -------------------------------------- - 192.5/197.8 MB 3.2 MB/s eta 0:00:02
#    -------------------------------------- - 192.7/197.8 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------------  192.9/197.8 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------------  193.0/197.8 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------------  193.2/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  193.3/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  193.5/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  193.7/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  193.8/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  194.0/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  194.2/197.8 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------------  194.4/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  194.5/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  194.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  195.1/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  195.4/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  195.5/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  195.7/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  195.8/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.0/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  196.2/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.2/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.2/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.4/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.6/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.8/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  196.9/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  197.1/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  197.2/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  197.2/197.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  197.4/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.6/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  197.8/197.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 197.8/197.8 MB 2.9 MB/s eta 0:00:00
# Downloading importlib_metadata-8.2.0-py3-none-any.whl (25 kB)
# Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    --------------------------------- ------ 112.6/133.3 kB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  133.1/133.3 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 133.3/133.3 kB 1.6 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.7 MB 3.6 MB/s eta 0:00:01
#    ------- -------------------------------- 0.3/1.7 MB 4.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.7 MB 4.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.7 MB 4.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.7 MB 4.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.4/1.7 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.2 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB 8.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.5/6.2 MB 4.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/6.2 MB 4.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.8/6.2 MB 4.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.2 MB 4.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.2/6.2 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 1.5/6.2 MB 4.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.7/6.2 MB 4.8 MB/s eta 0:00:01
#    ------------ --------------------------- 1.9/6.2 MB 4.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.2/6.2 MB 4.9 MB/s eta 0:00:01
#    --------------- ------------------------ 2.4/6.2 MB 5.0 MB/s eta 0:00:01
#    --------------- ------------------------ 2.5/6.2 MB 4.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.5/6.2 MB 4.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.5/6.2 MB 3.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.2 MB 3.9 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.2 MB 4.0 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.2 MB 4.0 MB/s eta 0:00:01
#    --------------------- ------------------ 3.3/6.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 3.8/6.2 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 4.1/6.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.4/6.2 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.6/6.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 4.8/6.2 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.2 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.4/6.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 5.6/6.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 5.7/6.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 5.9/6.2 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.2 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 3.9 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ------ --------------------------------- 81.9/536.2 kB 4.5 MB/s eta 0:00:01
#    ------------ --------------------------- 174.1/536.2 kB 3.5 MB/s eta 0:00:01
#    --------------- ------------------------ 204.8/536.2 kB 1.8 MB/s eta 0:00:01
#    --------------- ------------------------ 204.8/536.2 kB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 409.6/536.2 kB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 491.5/536.2 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 536.2/536.2 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: mpmath, zipp, sympy, networkx, jinja2, torch, importlib-metadata, diffusers, accelerate, transformers
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ADMIN\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\ADMIN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
# from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "openai/whisper-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=30,
    batch_size=16,
    return_timestamps=True,
    torch_dtype=torch_dtype,
    device=device,
)

# dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
# sample = dataset[0]["audio"]
sample = "/content/extracted_audio.mp3"
sample = r"C:\Users\ADMIN\NIKHIL PROGRAM FILES\DOMAIN WISE\VIDEO AND PHOTO EDITING\VIDEOS\AI VIDEO ENHANCER\AI VIDEO ENHANCER 00A001\pythonProject\Olu Video Song  Maniyarayile Ashokan  Sid Sriram  Sreehari K Nair  Gregory Jacob  Onima Kashyap.mp4"
result = pipe(sample)
print(result["text"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import torch
#       2 from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
#       3 # from datasets import load_dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.
